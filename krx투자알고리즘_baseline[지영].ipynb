# %% [markdown]
# ## Import

# %%
import pandas as pd
import numpy as np
import random
import os

from tqdm import tqdm
from statsmodels.tsa.arima.model import ARIMA

import warnings
warnings.filterwarnings("ignore")

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

seed_everything(42) # Seed 고정

# %% [markdown]
# ## Data Load

# %%
train = pd.read_csv('./train.csv')

# %% [markdown]
# ## Model Define, Train and Inference

# %%
# 추론 결과를 저장하기 위한 dataframe 생성
results_df = pd.DataFrame(columns=['종목코드', 'final_return'])

# train 데이터에 존재하는 독립적인 종목코드 추출
unique_codes = train['종목코드'].unique()

# 각 종목코드에 대해서 모델 학습 및 추론 반복
for code in tqdm(unique_codes):
    
    # 학습 데이터 생성
    train_close = train[train['종목코드'] == code][['일자', '종가']]
    train_close['일자'] = pd.to_datetime(train_close['일자'], format='%Y%m%d')
    train_close.set_index('일자', inplace=True)
    tc = train_close['종가']
    
    # 모델 선언, 학습 및 추론
    model = ARIMA(tc, order=(2, 1, 2))
    model_fit = model.fit()
    predictions = model_fit.forecast(steps=15) # 향후 15개의 거래일에 대해서 예측
    
    # 최종 수익률 계산
    final_return = (predictions.iloc[-1] - predictions.iloc[0]) / predictions.iloc[0]
    
    # 결과 저장
    results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
# Out:
#   0%|          | 0/2000 [00:03<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Yoojiyoung\Desktop\FELAB\KRX\krx투자알고리즘_baseline.ipynb Cell 7 in <module>
#      <a href='vscode-notebook-cell:/c%3A/Users/Yoojiyoung/Desktop/FELAB/KRX/krx%ED%88%AC%EC%9E%90%EC%95%8C%EA%B3%A0%EB%A6%AC%EC%A6%98_baseline.ipynb#W6sZmlsZQ%3D%3D?line=21'>22</a> final_return = (predictions.iloc[-1] - predictions.iloc[0]) / predictions.iloc[0]
#      <a href='vscode-notebook-cell:/c%3A/Users/Yoojiyoung/Desktop/FELAB/KRX/krx%ED%88%AC%EC%9E%90%EC%95%8C%EA%B3%A0%EB%A6%AC%EC%A6%98_baseline.ipynb#W6sZmlsZQ%3D%3D?line=23'>24</a> # 결과 저장
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Yoojiyoung/Desktop/FELAB/KRX/krx%ED%88%AC%EC%9E%90%EC%95%8C%EA%B3%A0%EB%A6%AC%EC%A6%98_baseline.ipynb#W6sZmlsZQ%3D%3D?line=24'>25</a> results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
#
# File c:\Users\Yoojiyoung\anaconda3\lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
# 추론 결과를 저장하기 위한 dataframe 생성
results_df = pd.DataFrame(columns=['종목코드', 'final_return'])

# train 데이터에 존재하는 독립적인 종목코드 추출
unique_codes = train['종목코드'].unique()

# 각 종목코드에 대해서 모델 학습 및 추론 반복
for code in tqdm(unique_codes):
    
    # 학습 데이터 생성
    train_close = train[train['종목코드'] == code][['일자', '종가']]
    train_close['일자'] = pd.to_datetime(train_close['일자'], format='%Y%m%d')
    train_close.set_index('일자', inplace=True)
    tc = train_close['종가']
    
    # 모델 선언, 학습 및 추론
    model = ARIMA(tc, order=(2, 1, 2))
    model_fit = model.fit()
    predictions = model_fit.forecast(steps=15) # 향후 15개의 거래일에 대해서 예측
    
    # 최종 수익률 계산
    final_return = (predictions.iloc[-1] - predictions.iloc[0]) / predictions.iloc[0]
    
    # 결과 저장
    result_row = {'종목코드': code, 'final_return': final_return}
    results_df = pd.concat([results_df, pd.DataFrame([result_row])], ignore_index=True)
# Out:
# 100%|██████████| 2000/2000 [40:15<00:00,  1.21s/it]

# %%
results_df['순위'] = results_df['final_return'].rank(method='first', ascending=False).astype('int') # 각 순위를 중복없이 생성
results_df
# Out:
#          종목코드  final_return    순위
# 0     A060310     -0.056255  1992
# 1     A095570     -0.002936  1686
# 2     A006840      0.003040   347
# 3     A054620      0.001859   484
# 4     A265520      0.002090   448
# ...       ...           ...   ...
# 1995  A189980      0.000630   727
# 1996  A000540      0.002514   394
# 1997  A003280      0.001430   545
# 1998  A037440      0.002151   443
# 1999  A238490      0.010894   113
#
# [2000 rows x 3 columns]

# %% [markdown]
# ## Submit

# %%
sample_submission = pd.read_csv('./sample_submission.csv')
sample_submission
# Out:
#          종목코드    순위
# 0     A000020     1
# 1     A000040     2
# 2     A000050     3
# 3     A000070     4
# 4     A000080     5
# ...       ...   ...
# 1995  A375500  1996
# 1996  A378850  1997
# 1997  A383220  1998
# 1998  A383310  1999
# 1999  A383800  2000
#
# [2000 rows x 2 columns]

# %%
baseline_submission = sample_submission[['종목코드']].merge(results_df[['종목코드', '순위']], on='종목코드', how='left')
baseline_submission
# Out:
#          종목코드    순위
# 0     A000020   496
# 1     A000040  1653
# 2     A000050   866
# 3     A000070  1077
# 4     A000080  1203
# ...       ...   ...
# 1995  A375500   749
# 1996  A378850   553
# 1997  A383220   612
# 1998  A383310   240
# 1999  A383800  1086
#
# [2000 rows x 2 columns]

# %%
baseline_submission.to_csv('baseline_submission.csv', index=False)
